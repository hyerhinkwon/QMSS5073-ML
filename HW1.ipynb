# %% [markdown]
# <a href="https://colab.research.google.com/github/hyerhinkwon/QMSS5073-ML/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## QMSS 5073 - Homework 1 Part A

# %% [markdown]
# ***1. Find the url for the mtcars dataset from the following website: https://vincentarelbundock.github.io/Rdatasets/datasets.html. Read through the "DOC" file to understand the variables in the dataset, then use the following url to import the data using pandas read_csv function. https://vincentarelbundock.github.io/Rdatasets/csv/datasets/mtcars.csv.***

# %%
#Import Python libraries.

import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
#Import the data using pandas read_csv function.

df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/mtcars.csv')

# %% [markdown]
# ***2. Display the first five rows of the data.***

# %%
df.head(n=5)
# Out:
#             rownames   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# ***3. For each category in the cyl column, calculate the average mpg for all cars with that cyl value.***

# %%
df.groupby('cyl')[['mpg']].mean()
# Out:
#            mpg
# cyl
# 4    26.663636
# 6    19.742857
# 8    15.100000

# %% [markdown]
# ***4. Create a histogram using the mpg column.***

# %%
#Import pyplot
from matplotlib import pyplot as plt

#Plot
df['mpg'].hist()
plt.xlabel('Miles/(US) gallon')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ***5. Choose two variables in the data and create a scatterplot.***

# %%
plt.scatter(df['wt'], df['hp'])
plt.title("Horsepower by weight of motormobiles")
plt.xlabel("Weight (1000 lbs)")
plt.ylabel("Gross horsepower")
# Out:
# Text(0, 0.5, 'Gross horsepower')

# %% [markdown]
# ##QMSS 5073 - Homework 1 Part B
#
# ***1. Find a tabular dataset that interests you that has "tidy" data. Tidy data has data that is ready for your data analysis.  For our tasks we want something where columns represent variables and rows represent unique observations.  Give a brief description of the dataset.  Provide a citation of the dataset (any format is fine).***
#
# For this assignment, I will be using RuPaul's Drag Race Contestant Data, a contestant-level data for RuPaul's Drag Race through Season 14 (Arel-Bundock).
#
# **References:**
# Arel-Bundock, V. (2022). RuPaul's Drag Race Contestant Data. Vincent Arel-Bundock's Github projects. *https://vincentarelbundock.github.io/Rdatasets/doc/dragracer/rpdr_contestants.html*.

# %%
df1 = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/dragracer/rpdr_contestants.csv')

# %% [markdown]
# ***2. Display the first five rows of the data.***

# %%
df1.head(n=5)
# Out:
#    rownames season         contestant  age         dob  \
# 0         1    S01  BeBe Zahara Benet   28  1981-03-20
# 1         2    S01       Nina Flowers   34  1974-02-22
# 2         3    S01  Rebecca Glasscock   26  1983-05-25
# 3         4    S01            Shannel   26  1979-07-03
# 4         5    S01             Ongina   26  1982-01-06
#
#                    hometown
# 0    Minneapolis, Minnesota
# 1      Bayamón, Puerto Rico
# 2  Fort Lauderdale, Florida
# 3         Las Vegas, Nevada
# 4   Los Angeles, California

# %% [markdown]
# ***3. Create a visualization using one or two variables from this data.***

# %%
df1['age'].hist()
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
